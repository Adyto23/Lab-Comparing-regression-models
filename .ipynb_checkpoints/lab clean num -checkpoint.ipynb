# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
display(customer_df.shape)
customer_df.head()
# Out:
# (9134, 24)
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
customer_df.isnull().sum()/len(customer_df)
# Out:
# Customer                         0.0
# State                            0.0
# Customer Lifetime Value          0.0
# Response                         0.0
# Coverage                         0.0
# Education                        0.0
# Effective To Date                0.0
# EmploymentStatus                 0.0
# Gender                           0.0
# Income                           0.0
# Location Code                    0.0
# Marital Status                   0.0
# Monthly Premium Auto             0.0
# Months Since Last Claim          0.0
# Months Since Policy Inception    0.0
# Number of Open Complaints        0.0
# Number of Policies               0.0
# Policy Type                      0.0
# Policy                           0.0
# Renew Offer Type                 0.0
# Sales Channel                    0.0
# Total Claim Amount               0.0
# Vehicle Class                    0.0
# Vehicle Size                     0.0
# dtype: float64

# %%
customer_df.columns = customer_df.columns.str.lower().str.replace(' ', '_')

# %%
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'])

# %%
numerical_df=customer_df.select_dtypes(np.number)
numerical_df.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %%
def continuous_discrete(variable):
    unique_values = variable.nunique()
    if unique_values > 100:
        return 'continuous'
        
    else:
        return 'discrete'

# %%
deff=numerical_df.apply(continuous_discrete)
deff
# Out:
# customer_lifetime_value          continuous
# income                           continuous
# monthly_premium_auto             continuous
# months_since_last_claim            discrete
# months_since_policy_inception      discrete
# number_of_open_complaints          discrete
# number_of_policies                 discrete
# total_claim_amount               continuous
# dtype: object

# %%
con_list=[]
dis_list=[]

for col in numerical_df.columns:
        if numerical_df[col].nunique()> 100:
            con_list.append(col)
        else:
            dis_list.append(col)

display(con_list)
display(dis_list)
# Out:
# ['customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'total_claim_amount']
# ['months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies']

# %%
for col in dis_list:
    numerical_df[col].hist(bins=10)
    plt.show()

# %%
for col in con_list:
    numerical_df[col].hist(bins=10)
    plt.show()

# %%
correlations_matrix = numerical_df.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
cols = numerical_df.select_dtypes('number').columns
df_sub = numerical_df.loc[:, cols]

lim = np.logical_and(df_sub < df_sub.quantile(0.99, numeric_only=False),
                     df_sub > df_sub.quantile(0.01, numeric_only=False))

lim
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                        True    True                  True
# 1                        True   False                  True
# 2                        True    True                  True
# 3                        True   False                  True
# 4                        True    True                  True
# ...                       ...     ...                   ...
# 9129                     True    True                  True
# 9130                     True    True                  True
# 9131                     True   False                  True
# 9132                     True    True                  True
# 9133                     True   False                  True
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                        True                           True
# 1                        True                           True
# ...

# %%
Q1 = numerical_df.quantile(0.25)
Q3 = numerical_df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# customer_lifetime_value           4967.915247
# income                           62320.000000
# monthly_premium_auto                41.000000
# months_since_last_claim             17.000000
# months_since_policy_inception       47.000000
# number_of_open_complaints            0.000000
# number_of_policies                   3.000000
# total_claim_amount                 275.256594
# dtype: float64

# %%
print(numerical_df < (Q1 - 1.5 * IQR)) |(numerical_df > (Q3 + 1.5 * IQR))
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                       False   False                 False
# 1                       False   False                 False
# 2                       False   False                 False
# 3                       False   False                 False
# 4                       False   False                 False
# ...                       ...     ...                   ...
# 9129                    False   False                 False
# 9130                    False   False                 False
# 9131                    False   False                 False
# 9132                    False   False                 False
# 9133                    False   False                 False
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                       False                          False
# 1                       False                          False
# ...

# %%
print(numerical_df.skew())
numerical_df.describe()
# Out:
# customer_lifetime_value          3.032280
# income                           0.286887
# monthly_premium_auto             2.123546
# months_since_last_claim          0.278586
# months_since_policy_inception    0.040165
# number_of_open_complaints        2.783263
# number_of_policies               1.253333
# total_claim_amount               1.714966
# dtype: float64
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
# ...

# %%
numerical_df.boxplot(grid=False, rot=100, fontsize=8)
# Out:
# <AxesSubplot:>

# %%
numerical_df.boxplot(column=['customer_lifetime_value'])
# Out:
# <AxesSubplot:>

# %%
print(numerical_df['customer_lifetime_value'].quantile(0.10))
print(numerical_df['customer_lifetime_value'].quantile(0.90))
# Out:
# 2661.7578346
# 15433.385306000006

# %%
numerical_df["customer_lifetime_value"] = np.where(numerical_df["customer_lifetime_value"] <2662.0, 2662.0,numerical_df['customer_lifetime_value'])
numerical_df["customer_lifetime_value"] = np.where(numerical_df["customer_lifetime_value"] >15433.0, 15433.0,numerical_df['customer_lifetime_value'])
print(numerical_df['customer_lifetime_value'].skew())
# Out:
# 0.8822145565513336

# %%
numerical_df.boxplot(column=['total_claim_amount'])
# Out:
# <AxesSubplot:>

# %%
print(numerical_df['total_claim_amount'].quantile(0.10))
print(numerical_df['total_claim_amount'].quantile(0.90))
# Out:
# 104.08485470000001
# 773.4335034000001

# %%
numerical_df['total_claim_amount'].describe()
# Out:
# count    9134.000000
# mean      434.088794
# std       290.500092
# min         0.099007
# 25%       272.258244
# 50%       383.945434
# 75%       547.514839
# max      2893.239678
# Name: total_claim_amount, dtype: float64

# %%
numerical_df["total_claim_amount"] = np.where(numerical_df["total_claim_amount"] <104.0, 104.0,numerical_df['total_claim_amount'])
numerical_df["total_claim_amount"] = np.where(numerical_df["total_claim_amount"] >773.0, 773.0,numerical_df['total_claim_amount'])
print(numerical_df['total_claim_amount'].skew())
# Out:
# 0.24916411183523468

# %%
numerical_df.boxplot(column=['customer_lifetime_value'])
# Out:
# <AxesSubplot:>

# %%
numerical_df.boxplot(column=['total_claim_amount'])
# Out:
# <AxesSubplot:>

# %%
numerical_df.isnull().sum()
# Out:
# customer_lifetime_value          0
# income                           0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# total_claim_amount               0
# dtype: int64

# %%
numerical_df.to_csv("numerical.csv")

# %%
### lab cleaning-categorical-data

# %%
customer_df.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
categoricals = customer_df.select_dtypes(object)
categoricals.head()
##effective_to_date  datetime64[ns] was not counted as categorical and not as num but will be added in the end should the need arise
# Out:
#   customer       state response  coverage education employmentstatus gender  \
# 0  BU79786  Washington       No     Basic  Bachelor         Employed      F
# 1  QZ44356     Arizona       No  Extended  Bachelor       Unemployed      F
# 2  AI49188      Nevada       No   Premium  Bachelor         Employed      F
# 3  WW63253  California       No     Basic  Bachelor       Unemployed      M
# 4  HB64268  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# 1      Suburban         Single   Personal Auto   Personal L3           Offer3
# 2      Suburban        Married   Personal Auto   Personal L3           Offer1
# 3      Suburban        Married  Corporate Auto  Corporate L2           Offer1
# 4         Rural         Single   Personal Auto   Personal L1           Offer1
#
# ...

# %%
categoricals.isna().sum()/len(categoricals)
# Out:
# customer            0.0
# state               0.0
# response            0.0
# coverage            0.0
# education           0.0
# employmentstatus    0.0
# gender              0.0
# location_code       0.0
# marital_status      0.0
# policy_type         0.0
# policy              0.0
# renew_offer_type    0.0
# sales_channel       0.0
# vehicle_class       0.0
# vehicle_size        0.0
# dtype: float64

# %%
display(categoricals['response'].value_counts())

## checked by each category to make sure that there are no empty values
# Out:
# No     7826
# Yes    1308
# Name: response, dtype: int64

# %%
categoricals.nunique()
# Out:
# customer            9134
# state                  5
# response               2
# coverage               3
# education              5
# employmentstatus       5
# gender                 2
# location_code          3
# marital_status         3
# policy_type            3
# policy                 9
# renew_offer_type       4
# sales_channel          4
# vehicle_class          6
# vehicle_size           3
# dtype: int64

# %%
categoricals.drop('customer', inplace=True, axis=1)

# %%
categoricals
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type        policy  \
# ...

# %%
## cannot see if there is a reason to clean or change titles , thinking abbout policy and type policy as it seems that they are connected

# %%
display(categoricals['policy'].value_counts())
# Out:
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: policy, dtype: int64

# %%
display(categoricals['policy_type'].value_counts())
# Out:
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: policy_type, dtype: int64

# %%
categoricals.drop('policy', inplace=True, axis=1)

# %%
categoricals
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type renew_offer_type  \
# ...

# %%
categoricals.nunique()
# Out:
# state               5
# response            2
# coverage            3
# education           5
# employmentstatus    5
# gender              2
# location_code       3
# marital_status      3
# policy_type         3
# renew_offer_type    4
# sales_channel       4
# vehicle_class       6
# vehicle_size        3
# dtype: int64

# %%
categoricals
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type renew_offer_type  \
# ...

# %%
for col in categoricals.columns:
    categoricals[col].hist(bins=10)
    plt.show()

# %%
### most of the cars that are bought are medsized - four door cars 

## large cars are not often bought

## most of the cars are bought by marries-families can assume that they are from the subburbs and employed 

## most of the buyer are either high school or with a BA , we can assume that by the amount that are bought by master and doctor that they are the luxury or sports ares (but not just)

## the most cars are bought from CA , arizona or oregon 

## please note that all of the above are assumptions therefor might differ from the final results

# %%
customer_df["effective_to_date"]
# Out:
# 0      2011-02-24
# 1      2011-01-31
# 2      2011-02-19
# 3      2011-01-20
# 4      2011-02-03
#           ...
# 9129   2011-02-10
# 9130   2011-02-12
# 9131   2011-02-06
# 9132   2011-02-03
# 9133   2011-02-14
# Name: effective_to_date, Length: 9134, dtype: datetime64[ns]

# %%
customer_df["effective_to_date"].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
customer_df['day_year'] = pd.to_datetime(customer_df["effective_to_date"]).dt.to_period('D')

customer_df['month_year'] = pd.to_datetime(customer_df["effective_to_date"]).dt.to_period('M')

customer_df['year_year'] = pd.to_datetime(customer_df["effective_to_date"]).dt.to_period('Y')

# %%
customer_df['month_year'] = pd.DatetimeIndex(customer_df['effective_to_date']).month
customer_df['day_year'] = pd.DatetimeIndex(customer_df['effective_to_date']).day
customer_df['year_year'] = pd.DatetimeIndex(customer_df['effective_to_date']).year
## added the data to numerical_df
numerical_df['month_year'] = pd.DatetimeIndex(customer_df['effective_to_date']).month
numerical_df['day_year'] = pd.DatetimeIndex(customer_df['effective_to_date']).day
numerical_df['year_year']= pd.DatetimeIndex(customer_df['effective_to_date']).year

# %%
customer_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
customer_df['month_year'].hist(bins=12)
# Out:
# <AxesSubplot:>

# %%
customer_df['day_year'].hist(bins=8)
# Out:
# <AxesSubplot:>

# %%
customer_df['year_year'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
## all of the purchases was done in 2011 and in jan and feb 
## in mid or end of the month there is a mild drop in purchases  (other months 1200 the drop is to 800-850)

# %%
numerical_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             15433.000000   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2662.000000       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(numerical_df)
scaled_features = scaler.transform(numerical_df)
#Convert to table format - MinMaxScaler
df_MinMax = pd.DataFrame(data=numerical_df, columns=["year_year", "day_year","month_year","total_claim_amount","income", "monthly_premium_auto"])

# %%
df_MinMax
# Out:
#       year_year  day_year  month_year  total_claim_amount  income  \
# 0          2011        24           2          384.811147   56274
# 1          2011        31           1          773.000000       0
# 2          2011        19           2          566.472247   48767
# 3          2011        20           1          529.881344       0
# 4          2011         3           2          138.130879   43836
# ...         ...       ...         ...                 ...     ...
# 9129       2011        10           2          198.234764   71941
# 9130       2011        12           2          379.200000   21604
# 9131       2011         6           2          773.000000       0
# 9132       2011         3           2          691.200000   21941
# 9133       2011        14           2          369.600000       0
#
#       monthly_premium_auto
# 0                       69
# 1                       94
# 2                      108
# 3                      106
# 4                       73
# ...
